# %%
import pandas as pd

# %%
fall_freezes = pd.read_csv('https://data.world/associatedpress/shrinking-winter-dates-of-the-first-freeze/workspace/file?filename=First_Fall_Freezes.csv')

# %%
fall = pd.read_csv('First_Fall_Freezes.csv')

# %%
print fall
# Out:
#     state_abbr              county      station      lat       lon   region  \
# 0           AL      Bullock County  USC00018438  32.0142  -85.7464    South
# 1           AL      Chilton County  USC00011694  32.8161  -86.6042    South
# 2           AL       Clarke County  USC00018178  31.9172  -87.7347    South
# 3           AL     Crenshaw County  USC00013816  31.8814  -86.2503    South
# 4           AL       Dallas County  USC00017366  32.4111  -87.0144    South
# 5           AL       DeKalb County  USC00018469  34.5686  -85.6064    South
# 6           AL         Hale County  USC00013511  32.7019  -87.5814    South
# 7           AL      Jackson County  USC00017304  34.6736  -86.0536    South
# 8           AL    Talladega County  USC00018024  33.4164  -86.1350    South
# 9           AR       Benton County  USC00032930  36.4261  -94.4481    South
# 10          AR      Bradley County  USC00037582  33.6044  -92.0997    South
# ...

# %%
fall.head()
# Out:
#   state_abbr           county      station      lat      lon region  \
# 0         AL   Bullock County  USC00018438  32.0142 -85.7464  South
# 1         AL   Chilton County  USC00011694  32.8161 -86.6042  South
# 2         AL    Clarke County  USC00018178  31.9172 -87.7347  South
# 3         AL  Crenshaw County  USC00013816  31.8814 -86.2503  South
# 4         AL    Dallas County  USC00017366  32.4111 -87.0144  South
#
#              division  thirty_year_median  thirty_year_mean  \
# 0  East South Central               310.0             310.5
# 1  East South Central               311.5             313.7
# 2  East South Central               322.5             322.3
# 3  East South Central               315.0             315.4
# 4  East South Central               322.0             322.6
#
#    noaa_1981_2010_normal  ...     2007   2008   2009   2010   2011   2012  \
# 0                  311.0  ...      NaN  304.0  310.0  303.0  294.0  314.0
# ...

# %%
fall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Columns: 110 entries, state_abbr to 2016
# dtypes: float64(105), object(5)
# memory usage: 601.6+ KB

# %%
spring = pd.read_csv('Last_Spring_Freezes.csv')

# %%
print spring
# Out:
#     state_abbr                 county      station      lat       lon  \
# 0           AL         Chilton County  USC00011694  32.8161  -86.6042
# 1           AL            Hale County  USC00013511  32.7019  -87.5814
# 2           AL        Crenshaw County  USC00013816  31.8814  -86.2503
# 3           AL         Jackson County  USC00017304  34.6736  -86.0536
# 4           AL          Dallas County  USC00017366  32.4111  -87.0144
# 5           AL       Talladega County  USC00018024  33.4164  -86.1350
# 6           AL          Clarke County  USC00018178  31.9172  -87.7347
# 7           AL         Bullock County  USC00018438  32.0142  -85.7464
# 8           AL          DeKalb County  USC00018469  34.5686  -85.6064
# 9           AZ          Navajo County  USC00024089  34.9094 -110.1544
# 10          AZ         Yavapai County  USC00024453  34.7522 -112.1114
# 11          AZ          La Paz County  USC00026250  34.1547 -114.2908
# ...

# %%
spring.head()
# Out:
#   state_abbr           county      station      lat      lon region  \
# 0         AL   Chilton County  USC00011694  32.8161 -86.6042  South
# 1         AL      Hale County  USC00013511  32.7019 -87.5814  South
# 2         AL  Crenshaw County  USC00013816  31.8814 -86.2503  South
# 3         AL   Jackson County  USC00017304  34.6736 -86.0536  South
# 4         AL    Dallas County  USC00017366  32.4111 -87.0144  South
#
#              division  thirty_year_median  thirty_year_mean  \
# 0  East South Central                88.0         87.423077
# 1  East South Central                81.0         83.555556
# 2  East South Central                77.0         77.740741
# 3  East South Central                97.5         96.730769
# 4  East South Central                66.0         67.181818
#
#    noaa_1981_2010_normal  ...   2007   2008  2009  2010  2011  2012  2013  \
# 0                   88.0  ...   99.0   86.0  98.0  67.0  97.0  52.0  88.0
# ...

# %%
spring.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Columns: 110 entries, state_abbr to 2016
# dtypes: float64(105), object(5)
# memory usage: 601.6+ KB

# %%
merged = pd.merge(fall, spring, on="state_abbr")

# %%
print merged
# Out:
#       state_abbr          county_x    station_x    lat_x     lon_x region_x  \
# 0             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 1             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 2             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 3             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 4             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 5             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 6             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 7             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 8             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 9             AL    Chilton County  USC00011694  32.8161  -86.6042    South
# 10            AL    Chilton County  USC00011694  32.8161  -86.6042    South
# ...

# %%
merged.head()
# Out:
#   state_abbr        county_x    station_x    lat_x    lon_x region_x  \
# 0         AL  Bullock County  USC00018438  32.0142 -85.7464    South
# 1         AL  Bullock County  USC00018438  32.0142 -85.7464    South
# 2         AL  Bullock County  USC00018438  32.0142 -85.7464    South
# 3         AL  Bullock County  USC00018438  32.0142 -85.7464    South
# 4         AL  Bullock County  USC00018438  32.0142 -85.7464    South
#
#            division_x  thirty_year_median_x  thirty_year_mean_x  \
# 0  East South Central                 310.0               310.5
# 1  East South Central                 310.0               310.5
# 2  East South Central                 310.0               310.5
# 3  East South Central                 310.0               310.5
# 4  East South Central                 310.0               310.5
#
#    noaa_1981_2010_normal_x   ...    2007_y  2008_y  2009_y  2010_y  2011_y  \
# 0                    311.0   ...      99.0    86.0    98.0    67.0    97.0
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15434 entries, 0 to 15433
# Columns: 219 entries, state_abbr to 2016_y
# dtypes: float64(210), object(9)
# memory usage: 25.9+ MB

# %%
merged.to_csv('merged.csv')

# %%
merged.drop_duplicates()
# Out:
#       state_abbr          county_x    station_x    lat_x     lon_x region_x  \
# 0             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 1             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 2             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 3             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 4             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 5             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 6             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 7             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 8             AL    Bullock County  USC00018438  32.0142  -85.7464    South
# 9             AL    Chilton County  USC00011694  32.8161  -86.6042    South
# 10            AL    Chilton County  USC00011694  32.8161  -86.6042    South
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15434 entries, 0 to 15433
# Columns: 219 entries, state_abbr to 2016_y
# dtypes: float64(210), object(9)
# memory usage: 25.9+ MB

# %%
merged.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 15404    False
# 15405    False
# 15406    False
# 15407    False
# 15408    False
# 15409    False
# 15410    False
# 15411    False
# 15412    False
# 15413    False
# 15414    False
# 15415    False
# 15416    False
# 15417    False
# 15418    False
# 15419    False
# 15420    False
# 15421    False
# 15422    False
# 15423    False
# 15424    False
# 15425    False
# 15426    False
# 15427    False
# 15428    False
# 15429    False
# 15430    False
# ...

# %%
merged = pd.merge(fall, spring, on="station")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700 entries, 0 to 699
# Columns: 219 entries, state_abbr_x to 2016_y
# dtypes: float64(210), object(9)
# memory usage: 1.2+ MB

# %%
merged.head()
# Out:
#   state_abbr_x         county_x      station    lat_x    lon_x region_x  \
# 0           AL   Bullock County  USC00018438  32.0142 -85.7464    South
# 1           AL   Chilton County  USC00011694  32.8161 -86.6042    South
# 2           AL    Clarke County  USC00018178  31.9172 -87.7347    South
# 3           AL  Crenshaw County  USC00013816  31.8814 -86.2503    South
# 4           AL    Dallas County  USC00017366  32.4111 -87.0144    South
#
#            division_x  thirty_year_median_x  thirty_year_mean_x  \
# 0  East South Central                 310.0               310.5
# 1  East South Central                 311.5               313.7
# 2  East South Central                 322.5               322.3
# 3  East South Central                 315.0               315.4
# 4  East South Central                 322.0               322.6
#
#    noaa_1981_2010_normal_x   ...    2007_y  2008_y  2009_y  2010_y  2011_y  \
# ...

# %%
merged.to_csv('merged.csv')

# %%
print fall.1917_x
# Out:
#   File "<ipython-input-24-4e76ecf5e522>", line 1
#     print fall.1917_x
#                   ^
# SyntaxError: invalid syntax

# %%
fall.columns = fall.columns.astype(str)

# %%
fall.info()

# %%
fall.head()

# %%
print fall.1917_x

# %%
print fall.1917

# %%
print fall."1917"

# %%
print fall.station

# %%
print fall[1917]

# %%
print fall["1917"]

# %%
print fall[:11]

# %%
fall.index()

# %%
fall.head()

# %%
fall.info()

# %%
print fall [10:110]

# %%
fall.columns[10:110]

# %%
print fall[10:110]

# %%
fall.loc[10:110]

# %%
fall.loc["1917":"2016"]

# %%
falls = fall.columns[10:110]

# %%
print falls

# %%
def winter_fall(objects):
    for obj in objects:
        length = (365-(obj-1))
        return length

# %%
winter_fall(falls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-8202cc5101a6> in <module>()
# ----> 1 winter_fall(falls)
#
# NameError: name 'falls' is not defined

# %%
import openpyxl

# %%
winter_fall(falls)
