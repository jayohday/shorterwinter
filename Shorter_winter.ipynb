# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('merged.xlsx')

# %%
type(wb)
# Out:
# openpyxl.workbook.workbook.Workbook

# %%
wb.get_sheet_names()
# Out:
# ['merged']

# %%
sheet = wb.get_sheet_by_name('merged')

# %%
sheet('A1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-80f0e38a9e9c> in <module>()
# ----> 1 sheet('A1')
#
# TypeError: 'Worksheet' object is not callable

# %%
sheet['A1']
# Out:
# <Cell merged.A1>

# %%
sheet['A1'].value

# %%
sheet['A2'].value
# Out:
# 0

# %%
sheet.columns[1]
# Out:
# (<Cell merged.B1>,
#  <Cell merged.B2>,
#  <Cell merged.B3>,
#  <Cell merged.B4>,
#  <Cell merged.B5>,
#  <Cell merged.B6>,
#  <Cell merged.B7>,
#  <Cell merged.B8>,
#  <Cell merged.B9>,
#  <Cell merged.B10>,
#  <Cell merged.B11>,
#  <Cell merged.B12>,
#  <Cell merged.B13>,
#  <Cell merged.B14>,
#  <Cell merged.B15>,
#  <Cell merged.B16>,
#  <Cell merged.B17>,
#  <Cell merged.B18>,
#  <Cell merged.B19>,
#  <Cell merged.B20>,
#  <Cell merged.B21>,
#  <Cell merged.B22>,
#  <Cell merged.B23>,
#  <Cell merged.B24>,
#  <Cell merged.B25>,
#  <Cell merged.B26>,
#  <Cell merged.B27>,
#  <Cell merged.B28>,
#  <Cell merged.B29>,
#  <Cell merged.B30>,
#  <Cell merged.B31>,
#  <Cell merged.B32>,
#  <Cell merged.B33>,
#  <Cell merged.B34>,
#  <Cell merged.B35>,
#  <Cell merged.B36>,
#  <Cell merged.B37>,
#  <Cell merged.B38>,
#  <Cell merged.B39>,
#  <Cell merged.B40>,
#  <Cell merged.B41>,
#  <Cell merged.B42>,
#  <Cell merged.B43>,
#  <Cell merged.B44>,
#  <Cell merged.B45>,
# ...
